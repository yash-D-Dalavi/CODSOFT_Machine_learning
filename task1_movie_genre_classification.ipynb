# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
with open("train_data.txt", encoding="utf-8") as f:
    train_lines = f.readlines()

with open("test_data.txt", encoding="utf-8") as f:
    test_lines = f.readlines()

with open("test_data_solution.txt", encoding="utf-8") as f:
    solution_lines = f.readlines()

# %%
train_data = [line.strip().split(":::") for line in train_lines]
test_data = [line.strip().split(":::") for line in test_lines]
solution_data = [line.strip().split(":::") for line in solution_lines]

# %%
train_df = pd.DataFrame(train_data, columns=["id", "title", "genre", "plot"])
test_df = pd.DataFrame(test_data, columns=["id", "title", "plot"])
solution_df = pd.DataFrame(solution_data, columns=["id", "title", "genre", "plot"])

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return text

train_df['plot'] = train_df['plot'].apply(clean_text)
test_df['plot'] = test_df['plot'].apply(clean_text)

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_train = tfidf.fit_transform(train_df['plot'])
X_test = tfidf.transform(test_df['plot'])

# %%
y_train = train_df['genre']
y_test_actual = solution_df['genre']

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
print("\nClassification Report:")
print(classification_report(y_test_actual, y_pred))

print("\nAccuracy Score:")
print("Accuracy:", accuracy_score(y_test_actual, y_pred))
# Out:
# Classification Report:
# C:\Users\yashd\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\yashd\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
#       action        0.48      0.28      0.36      1314
#        adult        0.59      0.23      0.33       590
#    adventure        0.58      0.16      0.25       775
#    animation        0.49      0.06      0.10       498
# ...

# %%
test_df['Predicted_Genre'] = y_pred
test_df.to_csv("predicted_genres.csv", index=False)
print("\n✅ Predictions saved to 'predicted_genres.csv'")
# Out:
# ✅ Predictions saved to 'predicted_genres.csv'
